# %%
from pathlib import Path
import pandas as pd

# folder with the 14 downloaded files
src = Path("/Users/vlad/Desktop/fmri/group_project/voxel_wise_permutation/test_datasets/bp_sigma_batch")

# optional: save merged file in your SCIF folder
out = Path("/Users/vlad/Desktop/fmri/group_project/voxel_wise_permutation/datasets/vv_prm_t.csv")

def sigma_from_name(p: Path) -> float:
    # vv_prm_t_sigma_1p75.csv -> 1.75
    return float(p.stem.split("_")[-1].replace("p", "."))

files = sorted(src.glob("vv_prm_t_sigma_*.csv"), key=sigma_from_name)
print("files found:", len(files))

df = pd.concat((pd.read_csv(f) for f in files), ignore_index=True)
#df = df.sort_values(["n", "sm_sigma", "snr"]).reset_index(drop=True)

print("rows:", len(df))
print("duplicates (n,snr,sm_sigma):", int(df.duplicated(["n", "snr", "sm_sigma"]).sum()))
print("unique sigmas:", sorted(df["sm_sigma"].unique()))

df.to_csv(out, index=False)
print("saved:", out)
# Out:
# files found: 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 17
#      14 files = sorted(src.glob("vv_prm_t_sigma_*.csv"), key=sigma_from_name)
#      15 print("files found:", len(files))
# ---> 17 df = pd.concat((pd.read_csv(f) for f in files), ignore_index=True)
#      18 #df = df.sort_values(["n", "sm_sigma", "snr"]).reset_index(drop=True)
#      20 print("rows:", len(df))
#
# File ~/Desktop/fmri/group_project/.venv/lib/python3.14/site-packages/pandas/core/reshape/concat.py:407, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     402 else:  # pragma: no cover
#     403     raise ValueError(
#     404         "Only can inner (intersect) or outer (union) join the other axis"
#     405     )
# --> 407 objs, keys, ndims = _clean_keys_and_objs(objs, keys)
#     409 if sort is lib.no_default:
#     410     if axis == 0:
#
# File ~/Desktop/fmri/group_project/.venv/lib/python3.14/site-packages/pandas/core/reshape/concat.py:808, in _clean_keys_and_objs(objs, keys)
#     805     objs = list(objs)
#     807 if len(objs) == 0:
# --> 808     raise ValueError("No objects to concatenate")
#     810 if keys is not None:
#     811     if not isinstance(keys, Index):
#
# ValueError: No objects to concatenate
